# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedharth123/SML_Lab_2264/blob/main/SML_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
a=pd.read_csv('/content/sample_data/california_housing_test.csv')
a
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
print("Mean of latitude",np.mean(a['latitude']))
print("Mean of housing_median_age",np.mean(a['housing_median_age']))
print("Mean of total_rooms",np.mean(a['total_rooms']))
print("Mean of total_bedrooms",np.mean(a['total_bedrooms']))
print("Variance of latitude",np.var(a['latitude']))
print("Variance of housing_median_age",np.var(a['housing_median_age']))
print("Variance of total_rooms",np.var(a['total_rooms']))
print("Variance of total_bedrooms",np.var(a['total_bedrooms']))
# Out:
# Mean of latitude 35.635389999999994
# Mean of housing_median_age 28.845333333333333
# Mean of total_rooms 2599.578666666667
# Mean of total_bedrooms 529.9506666666666
# Variance of latitude 4.5339804479
# Variance of housing_median_age 157.58541155555554
# Variance of total_rooms 4645033.750478223
# Variance of total_bedrooms 172710.9642328889

# %%
x=np.array([5,10,15,20])
plt.hist(a['total_bedrooms'],bins=5)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['total_bedrooms'],bins=10)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['total_bedrooms'],bins=15)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['total_bedrooms'],bins=20)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['housing_median_age'],bins=5)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['housing_median_age'],bins=10)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['housing_median_age'],bins=15)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['housing_median_age'],bins=20)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['total_rooms'],bins=5)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['total_rooms'],bins=10)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['total_rooms'],bins=15)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['total_rooms'],bins=20)
plt.title('Histogram with density')
plt.show()

# %%
x=np.array([5,10,15,20])
plt.hist(a['latitude'],bins=5)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['latitude'],bins=10)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['latitude'],bins=15)
plt.title('Histogram with density')
plt.show()

# %%
 x=np.array([5,10,15,20])
plt.hist(a['latitude'],bins=20)
plt.title('Histogram with density')
plt.show()

# %%
MLE= -20640/2*np.log2(2*np.pi)-20640 /2*np.log(4.56)-1/2*4.56*(50-35.63)**2
print("log-likelihood value for 50 =",MLE)
MLE= -20640/2*np.log2(2*np.pi)-20640 /2*np.log(4.56)-1/2*4.56*(75-35.63)**2
print("log-likelihood value for 75 =",MLE)
MLE= -20640/2*np.log2(2*np.pi)-20640 /2*np.log(4.56)-1/2*4.56*(80-35.63)**2
print("log-likelihood value for 80 =",MLE)
# Out:
# log-likelihood value for 50 = -43493.02246294569
# log-likelihood value for 75 = -46556.202462945694
# log-likelihood value for 80 = -47510.83846294569
